# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
newdf=pd.read_csv("hiring.csv")
print(newdf)
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
print(newdf.to_string())
print(newdf.shape)
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000
# (8, 4)

# %%
overall=newdf.drop(columns=['experience'])
print(overall.corr().to_string())
# Out:
#                             test_score(out of 10)  interview_score(out of 10)  salary($)
# test_score(out of 10)                    1.000000                    0.143066  -0.003004
# interview_score(out of 10)               0.143066                    1.000000   0.037820
# salary($)                               -0.003004                    0.037820   1.000000

# %%
print(newdf.describe().to_string())
# Out:
#        test_score(out of 10)  interview_score(out of 10)    salary($)
# count               7.000000                    8.000000      8.00000
# mean                7.857143                    7.875000  63000.00000
# std                 1.345185                    1.642081  11501.55269
# min                 6.000000                    6.000000  45000.00000
# 25%                 7.000000                    6.750000  57500.00000
# 50%                 8.000000                    7.500000  63500.00000
# 75%                 8.500000                    9.250000  70500.00000
# max                10.000000                   10.000000  80000.00000

# %%
newdf['experience']=newdf['experience'].fillna('zero')
newdf
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
from word2number import w2n
newdf['experience'] = newdf['experience'].apply(w2n.word_to_num)
newdf
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    NaN                           7      72000
# 7          11                    7.0                           8      80000

# %%
print(newdf['test_score(out of 10)'].mean())
# Out:
# 7.857142857142857

# %%
newdf['test_score(out of 10)']=newdf['test_score(out of 10)'].fillna(7.8)
newdf
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    7.8                           7      72000
# 7          11                    7.0                           8      80000

# %%
newdf.fillna(7.8,inplace= True)
print(newdf)
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    7.8                           7      72000
# 7          11                    7.0                           8      80000

# %%
from sklearn.linear_model import LinearRegression

# %%
x = newdf.drop(columns = ['interview_score(out of 10)'])
y = newdf["salary($)"]
print(x)
print(y)
# Out:
#    experience  test_score(out of 10)  salary($)
# 0           0                    8.0      50000
# 1           0                    8.0      45000
# 2           5                    6.0      60000
# 3           2                   10.0      65000
# 4           7                    9.0      70000
# 5           3                    7.0      62000
# 6          10                    7.8      72000
# 7          11                    7.0      80000
# 0    50000
# 1    45000
# 2    60000
# 3    65000
# 4    70000
# 5    62000
# 6    72000
# 7    80000
# Name: salary($), dtype: int64

# %%
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
ans=model.predict([[0,8.0,1],[5,6.0,1]])
print(ans)
# Out:
# [1. 1.]

# %%
x1=newdf
y1=newdf["salary($)"]
reg=LinearRegression()
reg.fit(x1,y1)
# Out:
# LinearRegression()

# %%
ans= model.predict([[2,9,6],[12,10,10]])
print(ans)
# Out:
# [ 6. 10.]

# %%
ans=reg.predict([[10,7.8,7,1],[11,7.0,1,0]])
print(ans)
# Out:
# [1.00000000e+00 2.71020399e-11]

# %%
from sklearn.model_selection import train_test_split
x_train,X_test,y_train,Y_test =train_test_split(x1,y1,test_size=0.33)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (5, 4)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 2
#       1 print(x_train.shape)
# ----> 2 print(x_test.shape)
#
# NameError: name 'x_test' is not defined
